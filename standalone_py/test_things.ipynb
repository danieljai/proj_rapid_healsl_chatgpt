# %%
import pandas as pd


# df = pd.read_csv('./output/s3_output_gpt3_sample.csv')
df = pd.read_csv('./output/healsl_rd1_rapid_gpt3_v2b.csv')

for c in df.columns:
    print(c)

# df[~df.cause2_icd10.isna()]
# Out:
# rowid
# cause1_icd10
# cause2_icd10
# cause3_icd10
# cause4_icd10
# cause5_icd10
# param_model
# param_system_prompt
# param_user_prompt
# param_max_tokens
# param_temperature
# output_created
# output_usage_completion_tokens
# output_usage_prompt_tokens
# output_msg
# icd10_count
# output_probs
# age_group
# round
# output

# %%
df
# Out:
#          rowid cause1_icd10 cause2_icd10  cause3_icd10  cause4_icd10  \
# 0     14002421          I10          NaN           NaN           NaN
# 1     14005966        S06.4          NaN           NaN           NaN
# 2     14001514          B54          NaN           NaN           NaN
# 3     14009193          I10          NaN           NaN           NaN
# 4     14002210          I61          NaN           NaN           NaN
# ...        ...          ...          ...           ...           ...
# 8565  14003026          P22          NaN           NaN           NaN
# 8566  14007876        P22.0          NaN           NaN           NaN
# 8567  14004971        P59.9          NaN           NaN           NaN
# 8568  14006360        P91.0          NaN           NaN           NaN
# 8569  14008409          P91          NaN           NaN           NaN
#
#       cause5_icd10                    output_created         param_model  \
# ...

# %%
pd.set_option('display.max_colwidth', 100)

for _, d in df.sample(10).iterrows():
    print(d[d != 0])
    print("-" * 100)
# Out:
# rowid                           24002976
# same_cause1_icd10_10x                  1
# cause_icd10                  {'G83': 10}
# same_cause1_cghr10_10x                 1
# cause_cghr10              {'Stroke': 10}
# age_group                          adult
# round                                rd2
# Name: 97, dtype: object
# ----------------------------------------------------------------------------------------------------
# rowid                                 14002600
# same_cause1_icd10_1x                         1
# same_cause1_icd10_9x                         1
# cause_icd10               {'B54': 9, 'B50': 1}
# same_cause1_cghr10_10x                       1
# cause_cghr10                   {'Malaria': 10}
# age_group                                child
# round                                      rd1
# Name: 19, dtype: object
# ----------------------------------------------------------------------------------------------------
# ...
