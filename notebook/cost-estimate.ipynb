# %%
import pandas as pd

# open the file as pd
df1 = pd.read_csv('../healsl_rd1to2_rapid_gpt3_v2b_2024_03_11/healsl_rd1_rapid_gpt3_v2b.csv')
df2 = pd.read_csv('../healsl_rd1to2_rapid_gpt3_v2b_2024_03_11/healsl_rd2_rapid_gpt3_v2b.csv')

# %%
print(df1.shape[0] + df2.shape[0])
# Out:
# 11887

# %%
df3 = pd.read_csv('./repeated_sampled_0308_parsed.csv')

df3
# Out:
#         rowid cause1_icd10  cause1_icd10_prob  cause2_icd10  \
# 0    14006015          J39           0.941054           NaN
# 1    14003152          J18           0.679123           NaN
# 2    14004789          V01           0.699564           NaN
# 3    14008356          N12           0.703657           NaN
# 4    14004298          K25           0.919672           NaN
# ..        ...          ...                ...           ...
# 995  24002603          G91           0.715795           NaN
# 996  24002738          B54           0.863337           NaN
# 997  24000569        G43.9           0.582239           NaN
# 998  24002421        P22.0           0.690923           NaN
# 999  24000133          P91           0.846587           NaN
#
#      cause2_icd10_prob  cause3_icd10  cause3_icd10_prob  cause4_icd10  \
# 0                  NaN           NaN                NaN           NaN
# 1                  NaN           NaN                NaN           NaN
# ...
