# %%
import os
import pandas as pd
import numpy as np
from openai import OpenAI
import textwrap
import datetime
import pytz
import json
import re


open_api_key = os.environ.get('OPEN_API_KEY')
client = OpenAI(api_key=open_api_key)

WORDWRAP_WIDTH = 100
DATA_FILE = "data_storage.json"
SAVE_FREQ = 5

# Models
GPT4 = "gpt-4-0613"
GPT3 = "gpt-3.5-turbo-0125"
MODEL_NAME = GPT3

# Set the timezone to Eastern Time
TIMEZONE = pytz.timezone('US/Eastern')



# SYS_PROMPT = """You are a physician with expertise in determining underlying causes of death in Sierra Leone 
# by assigning ICD-10 codes for deaths using verbal autopsy narratives. Return only the ICD-10 code in JSON format: {“icd10”: [code1, code2, code3, code4, code5]}"""

# SYS_PROMPT = """You are a physician with expertise in determining underlying causes of death in Sierra Leone 
# by assigning ICD-10 codes for deaths using verbal autopsy narratives. Return only the ICD-10 code in JSON format: {“icd10”: code1}"""

# USR_PROMPT = """Determine the underlying cause of death and provide an ICD-10 code for a verbal autopsy narrative
# of a AGE_VALUE_DEATH AGE_UNIT_DEATH old SEX_COD death in Sierra Leone: {open_narrative}"""

SYS_PROMPT = """You are a physician with expertise in determining underlying causes of death in Sierra Leone by assigning ICD-10 codes for deaths using verbal autopsy narratives. Return only the ICD-10 code without description. E.g. A00 
If there are multiple ICD-10 codes, show one code per line."""

USR_PROMPT = """With the highest certainty, determine the underlying cause of death and provide the most accurate ICD-10 code for a verbal autopsy narrative of a AGE_VALUE_DEATH AGE_UNIT_DEATH old SEX_COD death in Sierra Leone: {open_narrative}"""

# %%
# cost projection
# (((len(SYS_PROMPT + prompt) // 4) / 1000) * 0.0005 + (15/1000) * 0.0015 ) * 12000

# %%
questionnaire_df =  pd.read_csv("../data_202402/healsl_rd2_neo_v1.csv")
age_df =            pd.read_csv("../data_202402/healsl_rd2_neo_age_v1.csv")
narrative_df =      pd.read_csv("../data_202402/healsl_rd2_neo_narrative_v1.csv")

narrative_df = narrative_df.rename(columns={'summary': 'open_narrative'})

# %%
# quick_gp3 = pd.read_csv("../data_202402/healsl_rd1_rapid_chatgpt3_v1.csv")
# quick_gp4 = pd.read_csv("../data_202402/healsl_rd1_rapid_chatgpt4_v1.csv")

# questionnaire_df[questionnaire_df['p1_recon_icd_cod'].isna()][['rowid','p1_icd_cod','p2_icd_cod']]

# %%
narrative_only = narrative_df[['rowid','open_narrative']]
sex_only = questionnaire_df[['rowid','sex_cod']]
age_only = age_df[['rowid','age_value_death','age_unit_death']]

merged_df = narrative_only.merge(sex_only, on='rowid').merge(age_only, on='rowid')

# Fill in missing values with empty string
merged_df['sex_cod'] = merged_df['sex_cod'].fillna('')

assert not merged_df.isnull().values.any(), "Execution halted: NaN values found in merged_df"

print(f"Sample of merged_df {merged_df.shape}:")
display(merged_df.sample(5))
# Out:
# Sample of merged_df (233, 5):
#         rowid                                     open_narrative sex_cod  \
# 49   24000575  According to the respondent, the child was fre...    Male
# 58   24000637  As per respondent, the deceased child was 7 da...  Female
# 41   24001466  According to respondent, Deceased was a 21 day...    Male
# 206  24001487  The deceased was a 7 days old baby boy who was...    Male
# 170  24003526  According to the respondent the deceased was a...  Female
#
#      age_value_death age_unit_death
# 49                 0           Days
# 58                 7           Days
# 41                21           Days
# 206                7           Days
# 170                0           Days

# %%
# F(x): Initialize the data storage dictionary

def load_data(filename=DATA_FILE):
    
    if os.path.exists(filename):
        print(f"{filename} found. Loading data...")
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    else:
        print(f"{filename} not found. Initializing empty dictionary...")
        return {}

def save_data(data, filename=DATA_FILE):
    # Save data to a file    
    with open(filename, 'w') as file:
        json.dump(data, file)

# %%
# F(x): Send a message to the chatbot
def get_completion(
    messages: list[dict[str, str]],
    model: str = "gpt-3.5-turbo-0125",
    # model: str = "gpt-3.5-turbo-0125",
    # max_tokens=500,
    temperature=0,
    # stop=None,
    # seed=123,
    tools=None,
    logprobs=None,
    top_logprobs=None,
) -> str:

    params = {
        "model": model,
        # "response_format": { "type": "json_object" },
        "messages": messages,
        # "max_tokens": max_tokens,
        "temperature": temperature,
        # "stop": stop,
        # "seed": seed,
        "logprobs": logprobs,
        "top_logprobs": top_logprobs,
    }
    if tools:
        params["tools"] = tools

    completion = client.chat.completions.create(**params)
    return completion

# %%
# F(x): Extract ICD probabilities from tokens

def extract_icd_probabilities(logprobs):
    parsed_icd = []
    for pos in range(len(logprobs)):
        temp_df = pd.DataFrame(logprobs[pos: pos+4])
        temp_df = temp_df[temp_df[0].notna() & (temp_df[0].str.strip() != '')]
        temp_df = temp_df[temp_df[0].str.strip() != '\n']
        temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
        if len(temp_concat) > 9:
            continue
        # pattern = r'^[A-Z]\d{0,4}(\.\d{0,4})?$'
        pattern_4part = r'^[A-Z]\d{0,4}(\.\d{1,4})?$'
        match = re.match(pattern_4part, temp_concat)

        if match:
            # print(f"{temp_concat} - valid ICD {np.round((np.exp(temp_df.iloc[:, 1]).mean())*100,2)}%")
            # print(f"**** {temp_concat} - VALID 2-parts ICD ****")
            parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
        else:
            # print(f"{temp_concat} - invalid 4-parts.")
            
            #trying 2-parts
            temp_df = pd.DataFrame(logprobs[pos: pos+2])
            temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
            pattern_2part = r'^[A-Z]\d{1,4}$'
            match = re.match(pattern_2part, temp_concat)
            if match:
                # print(f"**** {temp_concat} - VALID 2-parts ICD ****")
                parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
            else:
                # print(f"{temp_concat} - invalid 2-parts.")
                pass
            pass

    return parsed_icd

# %%
import datetime
# Load existing data or initialize an empty dictionary
data_storage = load_data()
skipped_rows = []
repeated_skips = False
print()


for index, row in merged_df.iterrows():
    # Access the values of each column in the current row
    # hijacking row 
    # row = merged_df[merged_df['rowid'] == 14005966].iloc[0]
    
    rowid = row['rowid']
    
    # Check if rowid already processed. Testing both because json changes int keys to str    
    if (rowid) in data_storage or str(rowid) in data_storage:
        if repeated_skips:
            print("\r", end='', flush=True)
        print(f"Skipping index {index}, row {rowid} - Already processed.", end='', flush=True)
        repeated_skips = True
        skipped_rows.append(rowid)
        continue

    
    narrative = row['open_narrative']
    sex_cod = row['sex_cod']
    age_value_death = row['age_value_death']
    age_unit_death = row['age_unit_death']
    
    prompt = USR_PROMPT
    prompt = prompt.replace('AGE_VALUE_DEATH', str(age_value_death))
    prompt = prompt.replace('AGE_UNIT_DEATH', age_unit_death.lower())
    prompt = prompt.replace('SEX_COD', sex_cod.lower())
    prompt = prompt.format(open_narrative=narrative)
    
    # print("Prompt:")    
    # print(textwrap.fill(prompt, width=WORDWRAP_WIDTH))
    # print()
    
    # for a in range(5):
    completion = get_completion(
        [
            {"role": "system", "content": SYS_PROMPT},
            {"role": "user", "content": prompt}
        ] ,
        model=MODEL_NAME,
        logprobs=True,
        # top_logprobs=2,
    )
    
    # print(completion.choices[0].message)
    
    # for token in completion.choices[0].logprobs.content:
    #     print(f"{repr(str(token.token)).ljust(15)}  {str(token.logprob).ljust(20)} {np.round(np.exp(token.logprob)*100,2)}%")
        
    output_msg = completion.choices[0].message.content
    logprob_data = [(token.token, float(token.logprob)) for token in completion.choices[0].logprobs.content]
    usage_data = list(completion.usage)    
    current_time = datetime.datetime.now(tz=TIMEZONE).isoformat()
       
    data_storage[str(rowid)] = {
        'rowid': rowid,
        'model': MODEL_NAME,
        'system_prompt': SYS_PROMPT,
        'user_prompt': prompt,
        'output_msg': output_msg,
        'logprobs': logprob_data,
        'usage': usage_data,
        'timestamp': current_time
    }

    # Save data periodically (you can adjust the frequency based on your needs)    
    if index % SAVE_FREQ == 0 and index > 0:
        if repeated_skips:
            print("\n", flush=True)
        repeated_skips = False
        
        save_data(data_storage)
        print(f"Saving index: {str(index).ljust(8)} Processing: {str(rowid).ljust(12)} Rows skipped: {len(skipped_rows)}", sep=' ', end='\r', flush=True)
        # break
    
try:
    save_data(data_storage)
    print(f"Saving index: {str(index).ljust(8)} Processing: {str(rowid).ljust(12)} Rows skipped: {len(skipped_rows)}", sep=' ', end='\r', flush=True)
    print("\nData saved successfully.")
except Exception as e:
    print(f"Error saving data: {e}")

if len(skipped_rows) > 0:
    print(f"DF length: {len(merged_df)}")
    print(f"Rows skipped: {len(skipped_rows)}")
# Out:
# data_storage.json found. Loading data...
#
# Saving index: 232      Processing: 24001069     Rows skipped: 0
# Data saved successfully.

# %%
df = pd.DataFrame(data_storage).T
df['icds'] = df.apply(lambda x: extract_icd_probabilities(x['logprobs']), axis=1)
df['best_icd'] = df.apply(lambda x: pd.DataFrame(x['icds']).sort_values(by=1, ascending=False).iloc[0,0], axis=1)

# %%
df
# Out:
#              rowid               model  \
# 14002421  14002421  gpt-3.5-turbo-0125
# 14005966  14005966  gpt-3.5-turbo-0125
# 14001514  14001514  gpt-3.5-turbo-0125
# 14009193  14009193  gpt-3.5-turbo-0125
# 14002210  14002210  gpt-3.5-turbo-0125
# ...            ...                 ...
# 24002039  24002039  gpt-3.5-turbo-0125
# 24002598  24002598  gpt-3.5-turbo-0125
# 24001849  24001849  gpt-3.5-turbo-0125
# 24000702  24000702  gpt-3.5-turbo-0125
# 24001069  24001069  gpt-3.5-turbo-0125
#
#                                               system_prompt  \
# 14002421  You are a physician with expertise in determin...
# 14005966  You are a physician with expertise in determin...
# 14001514  You are a physician with expertise in determin...
# 14009193  You are a physician with expertise in determin...
# 14002210  You are a physician with expertise in determin...
# ...                                                     ...
# 24002039  You are a physician with expertise in determin...
# 24002598  You are a physician with expertise in determin...
# 24001849  You are a physician with expertise in determin...
# 24000702  You are a physician with expertise in determin...
# 24001069  You are a physician with expertise in determin...
#
#                                                 user_prompt output_msg  \
# 14002421  With the highest certainty, determine the unde...        I10
# 14005966  With the highest certainty, determine the unde...      S06.5
# 14001514  With the highest certainty, determine the unde...        B54
# 14009193  With the highest certainty, determine the unde...        I10
# 14002210  With the highest certainty, determine the unde...        I64
# ...                                                     ...        ...
# 24002039  With the highest certainty, determine the unde...      P91.0
# 24002598  With the highest certainty, determine the unde...      P22.9
# 24001849  With the highest certainty, determine the unde...        P91
# 24000702  With the highest certainty, determine the unde...      P02.1
# 24001069  With the highest certainty, determine the unde...      P95.0
#
#                                                    logprobs  \
# 14002421               [[I, -0.21676947], [10, -1.5235081]]
# 14005966  [[S, -0.05755939], [06, -0.111066304], [., -0....
# 14001514            [[B, -0.0049721203], [54, -0.46672902]]
# 14009193            [[I, -0.0077422047], [10, -0.15347986]]
# 14002210                [[I, -0.0280739], [64, -0.6882239]]
# ...                                                     ...
# 24002039  [(P, -0.0043068035), (91, -0.22353165), (., -0...
# 24002598  [(P, -0.00081963453), (22, -0.07494948), (., -...
# 24001849            [(P, -0.00037526153), (91, -1.1379366)]
# 24000702  [(P, -0.000562327), (02, -0.31716514), (., -0....
# 24001069  [(P, -0.003984012), (95, -0.067806385), (., -0...
#
#                                                       usage  \
# 14002421  [[completion_tokens, 2], [prompt_tokens, 375],...
# 14005966  [[completion_tokens, 4], [prompt_tokens, 294],...
# 14001514  [[completion_tokens, 2], [prompt_tokens, 363],...
# 14009193  [[completion_tokens, 2], [prompt_tokens, 539],...
# 14002210  [[completion_tokens, 2], [prompt_tokens, 366],...
# ...                                                     ...
# 24002039  [(completion_tokens, 4), (prompt_tokens, 537),...
# 24002598  [(completion_tokens, 4), (prompt_tokens, 414),...
# 24001849  [(completion_tokens, 2), (prompt_tokens, 277),...
# 24000702  [(completion_tokens, 4), (prompt_tokens, 463),...
# 24001069  [(completion_tokens, 4), (prompt_tokens, 470),...
#
#                                  timestamp                           icds  \
# 14002421  2024-02-15T14:20:38.369528-05:00    [(I10, 0.5115307596141437)]
# 14005966  2024-02-15T14:20:38.913306-05:00  [(S06.5, 0.8143644855324024)]
# 14001514  2024-02-15T14:20:39.477378-05:00    [(B54, 0.8110451028130556)]
# 14009193  2024-02-15T14:20:39.993528-05:00    [(I10, 0.9250028637177969)]
# 14002210  2024-02-15T14:20:40.480268-05:00    [(I64, 0.7373921099328329)]
# ...                                    ...                            ...
# 24002039  2024-02-15T21:35:43.111606-05:00  [(P91.0, 0.6976464789585074)]
# 24002598  2024-02-15T21:35:43.618831-05:00  [(P22.9, 0.7536376732273786)]
# 24001849  2024-02-15T21:35:44.080042-05:00    [(P91, 0.6600522132800508)]
# 24000702  2024-02-15T21:35:45.138545-05:00  [(P02.1, 0.8840350763999058)]
# 24001069  2024-02-15T21:35:45.630141-05:00  [(P95.0, 0.8334745330570872)]
#
#          best_icd
# 14002421      I10
# 14005966    S06.5
# 14001514      B54
# 14009193      I10
# 14002210      I64
# ...           ...
# 24002039    P91.0
# 24002598    P22.9
# 24001849      P91
# 24000702    P02.1
# 24001069    P95.0
#
# [11887 rows x 10 columns]

# %%
df[df['output_msg'].apply(lambda x:len(x) > 10)][['output_msg','icds','best_icd']]
# Out:
#                                                  output_msg  \
# 14002658  Malignant neoplasm of bone and articular carti...
# 14004747                           A09\nR50.9\nR11.0\nR63.4
# 14006258  V89.2 (Person injured in collision between oth...
# 14003822                                       T79.8\nR40.2
# 14007755                                       Tetanus: A33
# 14002323                                T79.3\nT88.9\nN17.9
# 14008510  V89.2 (Pedestrian injured in collision with ot...
# 14007670                                       Tetanus: A33
# 14008863  W17.89 - Other specified fall from one level t...
# 14001730                                       Malaria\nB54
# 14009106                                       O99.5\nO99.8
# 14005937                                       O99.5\nO16.2
# 14000201                  K29.5\nR57.0\nR11.2\nJ18.9\nK92.1
# 14005743                                       S82.8\nI21.9
# 14002258                                       T79.8\nT79.8
# 24002302                                       O99.8\nO99.1
# 24003037                                      T79.6\nJ96.00
# 24000721  V89.2 (Pedestrian injured in collision with ot...
# 24000129                                  H54\nI63.9\nR60.9
# 24000117                                       I50  \nJ18
# 24002070                                       L98.8\nB35.9
# 24000186                                J18.9\nR60.9\nR10.4
# 24001216                                       T79.8\nE11.9
# 24002029  V89.2 (Pedestrian injured in collision with he...
# 14006834                                       V89.2\nW22.8
# 14006130                                    Pneumonia J18.9
# 14000390                                  Pneumonia - J18.9
# 14002635                                     Pneumonia\nJ18
# 14008150                                   Pneumonia\nJ18.9
# 14005564                                  Pneumonia - J18.9
# 14006153                                    Pneumonia J18.9
# 14003220                           Nephrotic syndrome - N04
# 14006085                                   Pneumonia\nJ18.9
# 14000508                                     Pneumonia\nJ18
# 14002504                        P. falciparum malaria - B50
# 14002579                                  Pneumonia - J18.9
#
#                                                        icds best_icd
# 14002658                      [(C40.9, 0.8579251792598699)]    C40.9
# 14004747  [(A09, 0.3801835598412292), (R50.9, 0.66909530...    R50.9
# 14006258                      [(V89.2, 0.8129130625381266)]    V89.2
# 14003822  [(T79.8, 0.6216546258358351), (R40.2, 0.681784...    R40.2
# 14007755                        [(A33, 0.7714985657154876)]      A33
# 14002323  [(T79.3, 0.6682882892563279), (T88.9, 0.574929...    N17.9
# 14008510                      [(V89.2, 0.8549707965091256)]    V89.2
# 14007670                        [(A33, 0.7297871458081744)]      A33
# 14008863                     [(W17.89, 0.7211488803081331)]   W17.89
# 14001730  [(B54, 0.9215047096956849), (B54, 0.9215047096...      B54
# 14009106  [(O99.5, 0.9116210375779297), (O99.8, 0.760476...    O99.5
# 14005937  [(O99.5, 0.8627773477422638), (O16.2, 0.605538...    O99.5
# 14000201  [(K29.5, 0.5343298732313193), (R57.0, 0.761463...    R57.0
# 14005743  [(S82.8, 0.6480991921777641), (I21.9, 0.751666...    I21.9
# 14002258  [(T79.8, 0.7828274265073372), (T79.8, 0.553932...    T79.8
# 24002302  [(O99.8, 0.626245029320725), (O99.1, 0.6392571...    O99.1
# 24003037  [(T79.6, 0.4854299219029604), (J96.00, 0.60428...   J96.00
# 24000721  [(V89.2, 0.7230682932105017), (T79.6, 0.592590...  J45.909
# 24000129  [(H54, 0.4908481476030762), (I63.9, 0.72829587...    R60.9
# 24000117  [(I50, 0.6934470948653488), (J18, 0.9554432943...      J18
# 24002070  [(L98.8, 0.6579540552747636), (B35.9, 0.515544...    L98.8
# 24000186  [(J18.9, 0.7436831741851213), (R60.9, 0.760383...    R60.9
# 24001216  [(T79.8, 0.6004821416123383), (E11.9, 0.720779...    E11.9
# 24002029                       [(V89.2, 0.751837240960679)]    V89.2
# 14006834  [(V89.2, 0.8678651478309662), (W22.8, 0.518840...    V89.2
# 14006130                       [(J18.9, 0.753962601998909)]    J18.9
# 14000390                      [(J18.9, 0.8808717900852605)]    J18.9
# 14002635  [(J18, 0.992906752115695), (J18, 0.99290675211...      J18
# 14008150                      [(J18.9, 0.8749203170347692)]    J18.9
# 14005564                      [(J18.9, 0.9154916993107907)]    J18.9
# 14006153                      [(J18.9, 0.7916230968589624)]    J18.9
# 14003220                        [(N04, 0.9966137474329808)]      N04
# 14006085                      [(J18.9, 0.9001527520235466)]    J18.9
# 14000508  [(J18, 0.9943091639985449), (J18, 0.9943091639...      J18
# 14002504                        [(B50, 0.9913620784554851)]      B50
# 14002579                       [(J18.9, 0.894016402334684)]    J18.9

# %%
def extract_icd_probabilities(logprobs):
    parsed_icd = []
    for pos in range(len(logprobs)):
        temp_df = pd.DataFrame(logprobs[pos: pos+4])
        temp_df = temp_df[temp_df[0].notna() & (temp_df[0].str.strip() != '')]
        temp_df = temp_df[temp_df[0].str.strip() != '\n']
        temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
        if len(temp_concat) > 9:
            continue
        # pattern = r'^[A-Z]\d{0,4}(\.\d{0,4})?$'
        pattern_4part = r'^[A-Z]\d{0,4}(\.\d{1,4})?$'
        match = re.match(pattern_4part, temp_concat)

        if match:            
            print(f"**** {temp_concat} - VALID 4-parts ICD ****")

            

            display(temp_df)
            parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
        else:
            print(f"{temp_concat} - invalid 4-parts.")
            
            #trying 2-parts
            temp_df = pd.DataFrame(logprobs[pos: pos+2])
            temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
            pattern_2part = r'^[A-Z]\d{1,4}$'
            match = re.match(pattern_2part, temp_concat)
            if match:
                print(f"**** {temp_concat} - VALID 2-parts ICD ****")
                display(temp_df)
                parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
            else:
                print(f"{temp_concat} - invalid 2-parts.")
                pass
            pass

    return parsed_icd

print(data_storage['14000201']['output_msg'])
print()
print(extract_icd_probabilities(data_storage['14000201']['logprobs']))
# Out:
# K29.5
# R57.0
# R11.2
# J18.9
# K92.1
#
# **** K29.5 - VALID 4-parts ICD ****
#     0         1
# 0   K -0.226075
# 1  29 -1.688498
# 2   . -0.306559
# 3   5 -0.870149
# 29.5 - invalid 4-parts.
# 29. - invalid 2-parts.
# .5R - invalid 4-parts.
# .5 - invalid 2-parts.
# 5R57 - invalid 4-parts.
# 5 - invalid 2-parts.
# R57. - invalid 4-parts.
# R - invalid 2-parts.
# **** R57.0 - VALID 4-parts ICD ****
#     0         1
# 0   R -0.156713
# 1  57 -1.423716
# 2   . -0.018007
# 3   0 -0.032591
# 57.0 - invalid 4-parts.
# 57. - invalid 2-parts.
# .0R - invalid 4-parts.
# .0 - invalid 2-parts.
# 0R11 - invalid 4-parts.
# 0 - invalid 2-parts.
# R11. - invalid 4-parts.
# R - invalid 2-parts.
# **** R11.2 - VALID 4-parts ICD ****
#     0         1
# 0   R -0.532045
# 1  11 -1.047437
# 2   . -0.228074
# 3   2 -0.473701
# 11.2 - invalid 4-parts.
# 11. - invalid 2-parts.
# .2J - invalid 4-parts.
# .2 - invalid 2-parts.
# 2J18 - invalid 4-parts.
# 2 - invalid 2-parts.
# J18. - invalid 4-parts.
# J - invalid 2-parts.
# **** J18.9 - VALID 4-parts ICD ****
#     0         1
# 0   J -1.313691
# 1  18 -0.361045
# 2   . -0.005379
# 3   9 -0.005470
# 18.9 - invalid 4-parts.
# 18. - invalid 2-parts.
# .9K - invalid 4-parts.
# .9 - invalid 2-parts.
# 9K92 - invalid 4-parts.
# 9 - invalid 2-parts.
# K92. - invalid 4-parts.
# K - invalid 2-parts.
# **** K92.1 - VALID 4-parts ICD ****
#     0         1
# 0   K -0.503517
# 1  92 -1.109303
# 2   . -0.000008
# 3   1 -0.214341
# 92.1 - invalid 4-parts.
# 92. - invalid 2-parts.
# .1 - invalid 4-parts.
# .1 - invalid 2-parts.
# 1 - invalid 4-parts.
# 1 - invalid 2-parts.
# [('K29.5', 0.5343298732313193), ('R57.0', 0.761463588036748), ('R11.2', 0.5892493045547196), ('J18.9', 0.7387385413692558), ('K92.1', 0.6853138496405538)]

# %%
highest_output_indices = pd.DataFrame(data_storage).T.output_msg.apply(len).sort_values(ascending=False).head(10).index

def extract_icd_probabilities(logprobs):
    parsed_icd = []
    for pos in range(len(logprobs)):
        temp_df = pd.DataFrame(logprobs[pos: pos+4])
        temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
        if len(temp_concat) > 9:
            continue
        # pattern = r'^[A-Z]\d{0,4}(\.\d{0,4})?$'
        pattern_4part = r'^[A-Z]\d{0,4}(\.\d{1,4})?$'
        match = re.match(pattern_4part, temp_concat)

        if match:
            # print(f"{temp_concat} - valid ICD {np.round((np.exp(temp_df.iloc[:, 1]).mean())*100,2)}%")
            # print(f"**** {temp_concat} - VALID 2-parts ICD ****")
            parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
        else:
            # print(f"{temp_concat} - invalid 4-parts.")
            
            #trying 2-parts
            temp_df = pd.DataFrame(logprobs[pos: pos+2])
            temp_concat = ''.join(temp_df.iloc[:, 0]).strip()
            pattern_2part = r'^[A-Z]\d{1,4}$'
            match = re.match(pattern_2part, temp_concat)
            if match:
                # print(f"**** {temp_concat} - VALID 2-parts ICD ****")
                parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
            else:
                # print(f"{temp_concat} - invalid 2-parts.")
                pass
            pass

    return parsed_icd

for idx in highest_output_indices:
    print(f"Row {idx}:\n{data_storage[idx]['output_msg']}")
    print("---------")
    
    print(extract_icd_probabilities(data_storage[idx]['logprobs']))
    print()
    
    # for token, prob in data_storage[idx]['logprobs']:    
    #     print(f"{repr(token).ljust(15)}  {str(prob).ljust(20)} {np.round(np.exp(prob)*100,2)}%")
# Out:
# Row 24000721:
# V89.2 (Pedestrian injured in collision with other nonmotor vehicle in traffic accident)
# T79.6 (Traumatic shock)
# J45.909 (Unspecified asthma, uncomplicated)
# ---------
# [('V89.2', 0.7230682932105017), ('T79.6', 0.592590364029109), ('J45.909', 0.7467937316609086)]
#
# Row 24002029:
# V89.2 (Pedestrian injured in collision with heavy transport vehicle or bus)
# ---------
# [('V89.2', 0.751837240960679)]
#
# Row 14006258:
# V89.2 (Person injured in collision between other specified motor vehicles)
# ---------
# [('V89.2', 0.8129130625381266)]
#
# Row 14002658:
# Malignant neoplasm of bone and articular cartilage of lower limb - C40.9
# ---------
# [('C40.9', 0.8579251792598699)]
#
# Row 14008510:
# V89.2 (Pedestrian injured in collision with other nonmotor vehicle)
# ---------
# [('V89.2', 0.8549707965091256)]
#
# Row 14008863:
# W17.89 - Other specified fall from one level to another
# ---------
# [('W17.89', 0.7211488803081331)]
#
# Row 14000201:
# K29.5
# R57.0
# R11.2
# J18.9
# K92.1
# ---------
# [('K29.5', 0.5343298732313193), ('R57.0', 0.761463588036748), ('R11.2', 0.5892493045547196), ('J18.9', 0.7387385413692558), ('K92.1', 0.6853138496405538)]
#
# Row 14002504:
# P. falciparum malaria - B50
# ---------
# [('B50', 0.9913620784554851)]
#
# Row 14003220:
# Nephrotic syndrome - N04
# ---------
# [('N04', 0.9966137474329808)]
#
# Row 14004747:
# A09
# R50.9
# R11.0
# R63.4
# ---------
# [('A09', 0.3801835598412292), ('R50.9', 0.6690953098673259), ('R11.0', 0.5680976690938437), ('R63.4', 0.5916672403792442)]

# %%
print(f"output_msg: {data_storage[idx]['output_msg']}")



extract_icd_probabilities(data_storage[idx]['logprobs'])

# parsed_icd = []
# for pos in range(len(data_storage[idx]['logprobs'])):
#     temp_df = pd.DataFrame(data_storage[idx]['logprobs'][pos: pos+4])
#     temp_concat = ''.join(temp_df.iloc[:, 0])
#     pattern = r'^[A-Z]\d{0,4}(\.\d{0,4})?$'
#     match = re.match(pattern, temp_concat)

#     if match:
#         print(f"{temp_concat} - valid ICD {np.round((np.exp(temp_df.iloc[:, 1]).mean())*100,2)}%")
#         parsed_icd.append((temp_concat, (np.exp(temp_df.iloc[:, 1]).mean())))
#         # display(temp_df)
#         # print(f"{temp_df.iloc[:, 1].mean()}")
        
#         # print(np.round(np.exp(temp_df.iloc[:, 1])*100,2))
#         # print(np.round((np.exp(temp_df.iloc[:, 1]).mean())*100,2))
#     # else:
#     #     print(f"{temp_concat} - invalid ICD")
    
# print()
# print(parsed_icd)
# Out:
# output_msg: V89.2 (Pedestrian injured in collision with other nonmotor vehicle in traffic accident)
# T79.6 (Traumatic shock)
# J45.909 (Unspecified asthma, uncomplicated)
# [('V89.2', 0.7230682932105017),
#  ('T79.6', 0.592590364029109),
#  ('J45.909', 0.7467937316609086)]

# %%
# Inspect the length of the output message in descending order
print(pd.DataFrame(data_storage).T.output_msg.apply(len).sort_values(ascending=False))

id = 14000201    

for token, prob in data_storage[str(id)]['logprobs']:
    # print(token)
    print(f"{repr(token).ljust(15)}  {str(prob).ljust(20)} {np.round(np.exp(prob)*100,2)}%")
# Out:
# 14006258    74
# 14002658    72
# 14008510    67
# 14008863    55
# 14000201    29
#             ..
# 14007632     3
# 14006372     3
# 14004451     3
# 14007089     3
# 14002421     3
# Name: output_msg, Length: 4987, dtype: int64
# 'K'              -0.22607501          79.77%
# '29'             -1.6884981           18.48%
# '.'              -0.30655864          73.6%
# '5'              -0.8701493           41.89%
# '\n'             -0.4392439           64.45%
# 'R'              -0.15671347          85.49%
# '57'             -1.4237156           24.08%
# '.'              -0.018007351         98.22%
# '0'              -0.0325914           96.79%
# '\n'             -0.101339765         90.36%
# 'R'              -0.53204507          58.74%
# '11'             -1.0474371           35.08%
# '.'              -0.22807407          79.61%
# '2'              -0.47370052          62.27%
# '\n'             -0.19613144          82.19%
# 'J'              -1.3136908           26.88%
# '18'             -0.36104503          69.69%
# '.'              -0.0053791376        99.46%
# '9'              -0.0054697245        99.45%
# '\n'             -0.37257245          68.9%
# 'K'              -0.5035174           60.44%
# '92'             -1.1093025           32.98%
# '.'              -7.58424e-06         100.0%
# '1'              -0.21434106          80.71%

# %%
rowid
# Out:
# 14001514

# %%
rowid

# %%
pd.read_json(DATA_FILE).T.to_json()
# pd.read_json(DATA_FILE), orient='records')

# %%
pd.DataFrame(data_storage)

# %%
import json
import json

def save_data_storage(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

def load_data_storage(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Save the data_storage dictionary
save_data_storage(data_storage, 'data_storage.json')

# Reload the data_storage dictionary
data_storage = load_data_storage('data_storage.json')

# %%
type(data_storage)

# %%
data_storage_1

# %%
pd.DataFrame(data_storage).T

# %%
output_msg = completion.choices[0].message.content
logprob_data = [(token.token, float(token.logprob)) for token in completion.choices[0].logprobs.content]
usage_data = list(completion.usage)
    
for c in completion.usage:
    print(c)

print()
print(output_msg)
print(logprob_data)
print(usage_data)

# %%
list(completion.choices[0].logprobs.content)

# %%
for c in completion.choices[0]:
    print(c)

# %%
for c in completion:
    print(c)

print("------------------")
for c in completion.choices[0]:
    print(c)

# %%
import json
final_string = ""
for c in completion.choices[0].logprobs.content:
    final_string += c.token
    # print(c.token, sep="")

final_string

final_object = json.loads(final_string)
print(final_object['icd10'])

icd_code_pos = 0

for token in completion.choices[0].logprobs.content:
        print(f"{str(token.token).ljust(15)}  {str(token.logprob).ljust(20)} {np.round(np.exp(token.logprob)*100,2)}%")

# %%
test = get_completion(
        [
            {"role": "system", "content": SYS_PROMPT},
            {"role": "user", "content": prompt}
        ],
        model=3.5,
        logprobs=True,
        # top_logprobs=2,
    )

print(test.choices[0].message)

for token in test.choices[0].logprobs.content:
    print(f"{str(token.token).ljust(15)}  {str(token.logprob).ljust(20)} {np.round(np.exp(token.logprob)*100,2)}%")

# %%
params = {
        "model": 2,
        "response_format": { type: "json_object" },
        "messages": 5,
        # "max_tokens": max_tokens,
        "temperature": 1,
        # "stop": stop,
        # "seed": seed,
        "logprobs": 3,
        "top_logprobs": 4,
    }

print(**params)
